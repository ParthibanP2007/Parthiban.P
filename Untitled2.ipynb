# %%
# 1. Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# 2. Load Dataset
# Example: Mall Customers dataset (replace with your dataset if available)
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"  # using iris just as sample
df = pd.read_csv(url)

# For demonstration, let’s use only numerical columns (like spending, income in real dataset)
X = df.select_dtypes(include=[np.number])

print("Dataset shape:", X.shape)
X.head()
# Out:
# Dataset shape: (150, 4)
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# Scale features before clustering
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

inertia_values = []
k_range = range(1, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia_values.append(kmeans.inertia_)

# Plot Elbow Curve
plt.plot(k_range, inertia_values, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method")
plt.show()

# %%
# Let’s fit KMeans with k=3 (example, based on elbow)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# Check cluster centers
cluster_centers = pd.DataFrame(scaler.inverse_transform(kmeans.cluster_centers_),
                               columns=X.columns)
print(cluster_centers)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0      5.801887     2.673585      4.369811     1.413208
# 1      5.006000     3.428000      1.462000     0.246000
# 2      6.780851     3.095745      5.510638     1.972340

# %%
# Reduce dimensions using first 2 features for visualization
plt.figure(figsize=(6,5))
sns.scatterplot(x=X_scaled[:,0], y=X_scaled[:,1], hue=df['Cluster'], palette="Set2")
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
            s=200, c='red', marker='X', label='Centers')
plt.title("Cluster Visualization")
plt.legend()
plt.show()

# %%
print("Inertia (within-cluster sum of squares):", kmeans.inertia_)
# Out:
# Inertia (within-cluster sum of squares): 139.82049635974968

# %%
# Already done above using StandardScaler
print("Scaled data sample:\n", X_scaled[:5])
# Out:
# Scaled data sample:
#  [[-0.90068117  1.01900435 -1.34022653 -1.3154443 ]
#  [-1.14301691 -0.13197948 -1.34022653 -1.3154443 ]
#  [-1.38535265  0.32841405 -1.39706395 -1.3154443 ]
#  [-1.50652052  0.09821729 -1.2833891  -1.3154443 ]
#  [-1.02184904  1.24920112 -1.34022653 -1.3154443 ]]

# %%
score = silhouette_score(X_scaled, df['Cluster'])
print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.45994823920518646

# %%
# Average values of each cluster
cluster_profile = df.groupby('Cluster')[X.columns].mean()
print(cluster_profile)
# Out:
#          sepal_length  sepal_width  petal_length  petal_width
# Cluster
# 0            5.801887     2.673585      4.369811     1.413208
# 1            5.006000     3.428000      1.462000     0.246000
# 2            6.780851     3.095745      5.510638     1.972340

# %%
# Example: Add cluster labels to customer data
df[['Cluster']].head()
# Out:
#    Cluster
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
